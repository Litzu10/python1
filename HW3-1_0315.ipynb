# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\litzu\Desktop\python\03-11-2020.csv")
df
# Out:
#             Province/State                  Country/Region  \
# 0                    Hubei                           China
# 1                      NaN                           Italy
# 2                      NaN                            Iran
# 3                      NaN                    Korea, South
# 4                   France                          France
# 5                      NaN                           Spain
# 6                      NaN                         Germany
# 7                Guangdong                           China
# 8                    Henan                           China
# 9                 Zhejiang                           China
# 10                   Hunan                           China
# 11                   Anhui                           China
# 12                 Jiangxi                           China
# 13                Shandong                           China
# 14        Diamond Princess                     Cruise Ship
# ...

# %%
dfSort=df.sort_values(by=['Confirmed', 'Deaths'], ascending=False)
dfSort
# Out:
#             Province/State                  Country/Region  \
# 0                    Hubei                           China
# 1                      NaN                           Italy
# 2                      NaN                            Iran
# 3                      NaN                    Korea, South
# 4                   France                          France
# 5                      NaN                           Spain
# 6                      NaN                         Germany
# 7                Guangdong                           China
# 8                    Henan                           China
# 9                 Zhejiang                           China
# 10                   Hunan                           China
# 11                   Anhui                           China
# 12                 Jiangxi                           China
# 13                Shandong                           China
# 14        Diamond Princess                     Cruise Ship
# ...

# %%
a=df[['Country/Region', 'Confirmed', 'Deaths']] 
a
# Out:
#                      Country/Region  Confirmed  Deaths
# 0                             China      67773    3046
# 1                             Italy      12462     827
# 2                              Iran       9000     354
# 3                      Korea, South       7755      60
# 4                            France       2281      48
# 5                             Spain       2277      54
# 6                           Germany       1908       3
# 7                             China       1356       8
# 8                             China       1273      22
# 9                             China       1215       1
# 10                            China       1018       4
# 11                            China        990       6
# 12                            China        935       1
# 13                            China        760       6
# 14                      Cruise Ship        696       7
# 15                      Switzerland        652       4
# ...

# %%
b=a.head(31)
b
# Out:
#     Country/Region  Confirmed  Deaths
# 0            China      67773    3046
# 1            Italy      12462     827
# 2             Iran       9000     354
# 3     Korea, South       7755      60
# 4           France       2281      48
# 5            Spain       2277      54
# 6          Germany       1908       3
# 7            China       1356       8
# 8            China       1273      22
# 9            China       1215       1
# 10           China       1018       4
# 11           China        990       6
# 12           China        935       1
# 13           China        760       6
# 14     Cruise Ship        696       7
# 15     Switzerland        652       4
# 16           Japan        639      15
# 17           China        631       0
# 18          Norway        598       0
# 19           China        576       6
# 20           China        539       3
# 21     Netherlands        503       5
# 22          Sweden        500       1
# 23           China        482      13
# ...

# %%
b.plot(kind='bar')
