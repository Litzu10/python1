# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n = int(input ('n = '))
x = np.arange(0,n)
y = np.sin(x * np.pi / 180.0)
# Out:
# n = 360

# %%
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("sin.pic")
plt.xlim(-30,390)
plt.ylim(-1.5,1.5)
plt.show()
